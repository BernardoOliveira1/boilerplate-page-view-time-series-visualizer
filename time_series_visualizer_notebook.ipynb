# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Import data (Make sure to parse dates. Consider setting index column to 'date'.)
df = pd.read_csv('fcc-forum-pageviews.csv', parse_dates=True)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date')




# Clean data by filtering out days when the page views were in the top 2.5% of the dataset or bottom 2.5% of the dataset.
df_clean = df[(df['value']>=df['value'].quantile(0.025))&(df['value']<=df['value'].quantile(0.975))].copy()






# def draw_line_plot():
#     # Draw line plot



# x = df_clean['date']
# y = df_clean['value']

# plt.figure(figsize=(16,4))

# plt.plot(x, y,color= 'red')
# plt.xlabel("Date")  
# plt.ylabel("Page Views")  
# plt.title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019") 

# plt.show()
# fig = plt.gcf()





# # Save image and return fig (don't change this part)
# fig.savefig('line_plot.png')
#     return fig




# def draw_bar_plot():
#     # Copy and modify data for monthly bar plot
df_bar = df_clean.copy()    

#Months
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']


#create a column for Years and Months from the date column
df_bar['year'] = df_bar['date'].dt.year
df_bar['month'] = df_bar['date'].dt.month



#Map month integers to their proper names
df_bar["month"] = df_bar["month"].apply(
    lambda data: months[data-1]
)
#Make this a categorical column so it can be sorted by the order of values\
# in the `months` list, i.e., the proper month order: df_bar["month"] -> value; months -> categories
# In other words, we can properly sort the months from January to December in the DataFrame

df_bar["month"] = pd.Categorical(df_bar["month"], categories=months, ordered=True)


# Pivot the DF so that there's a column for each month, each row\
# represents a year, and the cells have the mean page views for the\
# respective year and month
# df_pivot = pd.pivot_table(
# 	df_bar,
#     ##TODO: mudar de value para page_views
# 	values="value",
# 	index="year",
# 	columns="month",
# 	aggfunc=np.mean
# )


# Plot a bar chart using the DF
# ax = df_pivot.plot(kind="bar")

# fig = ax.get_figure()

# fig.set_size_inches(7, 6)

# ax.set_xlabel("Years")
# ax.set_ylabel("Average Page Views")


# fig.savefig("page_views_barplot.png")


#     # Draw bar plot


# plt.figure(figsize=(16,4))

# plt.plot(x, y,color= 'red')
# plt.xlabel("Date")  
# plt.ylabel("Page Views")  
# plt.title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019") 

# plt.show()
# fig = plt.gcf()




#     # Save image and return fig (don't change this part)
#     fig.savefig('bar_plot.png')
#     return fig


## draw_box_plot():
    # Prepare data for box plots (this part is done!)
months_short = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df_box = df_clean.copy()
df_box.reset_index(inplace=True)
df_box['year'] = [d.year for d in df_box.date]
df_box['month'] = [d.strftime('%b') for d in df_box.date]
df_box['month'] = pd.Categorical(df_box['month'], categories=months_short, ordered=True)

sns.boxplot(x=df_box['year'], y=df_box['value'],).set(title='Boxplot of Total Bill by Day', xlabel='Year', ylabel='Page Views', )
plt.show()
sns.boxplot(x=df_box['month'], y=df_box['value'],).set(title='Month-wise Box Plot (Seasonality)', xlabel='Month', ylabel='Page Views')
plt.show()

    # Draw box plots (using Seaborn)

# %%
def draw_bar_plot():
    # Copy and modify data for monthly bar plot
    df_bar = None

    # Draw bar plot





    # Save image and return fig (don't change this part)
    fig.savefig('bar_plot.png')
    return fig

# %%
def draw_box_plot():
    # Prepare data for box plots (this part is done!)
    df_box = df.copy()
    df_box.reset_index(inplace=True)
    df_box['year'] = [d.year for d in df_box.date]
    df_box['month'] = [d.strftime('%b') for d in df_box.date]

    # Draw box plots (using Seaborn)





    # Save image and return fig (don't change this part)
    fig.savefig('box_plot.png')
    return fig
